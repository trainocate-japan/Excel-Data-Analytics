# %% [markdown]
# # 〜研修へようこそ
#
# 資料 URL:
# [Excelシート](img/最新_講義用Excelシート.xlsx)
#
# [ホテルレビューデータ](img/ホテルレビュー.csv)
#
# Zoom:https://trainocate-japan.zoom.us/j/98695291918?pwd=ytQjMquKbE4HaV5tjZ8cPi03wUuL4I.1
